# %% [markdown]
# # Day 7 - Part 1

# %%
class Beam:
    children = []
    count = 0
    splits = 0
    def __init__(self, manifold, position):
        self.position = position
        self.manifold = manifold
        self.destroyed = False
        Beam.count += 1

        self.travel()

    def travel(self):
        while self.position[0] < len(self.manifold) - 1:
            row = self.position[0]
            col = self.position[1]
            line = self.manifold[row]
            self.manifold[row] = line[:col] + '|' + line[col + 1:]
            if self.manifold[row + 1][col] == '^':
                self.split((row + 1, col + 1))
                self.split((row + 1, col - 1))
                Beam.splits += 1
                self.position = (row + 1, col)
                self.destroyed = True
                break

            self.position = (row + 1, col)

    def split(self, splitter_pos):
        self.children.append(Beam(self.manifold, splitter_pos))

with open("manifold_t.txt", 'r', encoding='utf-8') as f:
    manifold = [line.strip() for line in f.readlines()]

start_pos = (0, manifold[0].index('S'))
og_beam = Beam(manifold, start_pos)
print(Beam.count)

for b in set([t.position for t in og_beam.children if not t.destroyed]):
    line = manifold[b[0]]
    manifold[b[0]] = line[:b[1]] + '|' + line[b[1]+1:]

for line in manifold:
    print(line)

mask = [1 if c == '|' else 0 for c in manifold[-1]]
print(sum(mask))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 36
#      33     manifold = [line.strip() for line in f.readlines()]
#      35 start_pos = (0, manifold[0].index('S'))
# ---> 36 og_beam = Beam(manifold, start_pos)
#      37 print(Beam.count)
#      39 for b in set([t.position for t in og_beam.children if not t.destroyed]):
#
# Cell In[70], line 11, in Beam.__init__(self, manifold, position)
#       8 self.destroyed = False
#       9 Beam.count += 1
# ---> 11 self.travel()
#
# Cell In[70], line 20, in Beam.travel(self)
#      18 self.manifold[row] = line[:col] + '|' + line[col + 1:]
#      19 if self.manifold[row + 1][col] == '^':
# ---> 20     self.split((row + 1, col + 1))
#      21     self.split((row + 1, col - 1))
#      22     Beam.split += 1
#
# Cell In[70], line 30, in Beam.split(self, splitter_pos)
#      29 def split(self, splitter_pos):
# ---> 30     self.children.append(Beam(self.manifold, splitter_pos))
#
# Cell In[70], line 11, in Beam.__init__(self, manifold, position)
#       8 self.destroyed = False
#       9 Beam.count += 1
# ---> 11 self.travel()
#
# Cell In[70], line 20, in Beam.travel(self)
#      18 self.manifold[row] = line[:col] + '|' + line[col + 1:]
#      19 if self.manifold[row + 1][col] == '^':
# ---> 20     self.split((row + 1, col + 1))
#      21     self.split((row + 1, col - 1))
#      22     Beam.split += 1
#
# Cell In[70], line 30, in Beam.split(self, splitter_pos)
#      29 def split(self, splitter_pos):
# ---> 30     self.children.append(Beam(self.manifold, splitter_pos))
#
#     [... skipping similar frames: Beam.__init__ at line 11 (4 times), Beam.split at line 30 (3 times), Beam.travel at line 20 (3 times)]
#
# Cell In[70], line 20, in Beam.travel(self)
#      18 self.manifold[row] = line[:col] + '|' + line[col + 1:]
#      19 if self.manifold[row + 1][col] == '^':
# ---> 20     self.split((row + 1, col + 1))
#      21     self.split((row + 1, col - 1))
#      22     Beam.split += 1
#
# Cell In[70], line 30, in Beam.split(self, splitter_pos)
#      29 def split(self, splitter_pos):
# ---> 30     self.children.append(Beam(self.manifold, splitter_pos))
#
# Cell In[70], line 11, in Beam.__init__(self, manifold, position)
#       8 self.destroyed = False
#       9 Beam.count += 1
# ---> 11 self.travel()
#
# Cell In[70], line 22, in Beam.travel(self)
#      20 self.split((row + 1, col + 1))
#      21 self.split((row + 1, col - 1))
# ---> 22 Beam.split += 1
#      23 self.position = (row + 1, col)
#      24 self.destroyed = True
#
# TypeError: unsupported operand type(s) for +=: 'function' and 'int'
